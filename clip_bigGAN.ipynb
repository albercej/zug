# %% [markdown]
# <a href="https://colab.research.google.com/github/albercej/zug/blob/master/clip_bigGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CLIP + BigGAN & SIREN

# %%
COLAB = True

# %%
# --- Remember to change the runtime to use GPU for better performance
if COLAB:
    # !nvidia-smi
    # !pip install -Uqq big-sleep
    # !pip install -Uqq deep-daze
# Out:
# Wed Dec 21 16:06:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from big_sleep.cli import train as tti_big_sleep

# %%
name = "alejandro cejudo serrano"
tti_big_sleep(name, iterations = 100, epochs=5, overwrite=True)
# Out:
# Starting up... v0.9.1
# setting seed of 0
# you can override this with --seed argument in the command line, or --random for a randomly chosen one
# 100%|████████████████████████████████████████| 354M/354M [00:02<00:00, 121MiB/s]
# ...
# 100%|██████████| 800/800 [00:00<00:00, 356506.93B/s]
# Imagining "alberto_cejudo_podio" ...
# ...
# loss: -22.74:  49%|████▉     | 49/100 [00:27<00:27,  1.85it/s]
#
# image update:  10%|█         | 1/10.0 [00:27<04:11, 27.97s/it]
# ...
# loss: -26.59:  99%|█████████▉| 99/100 [00:54<00:00,  1.83it/s]
#
# image update:  20%|██        | 2/10.0 [00:55<03:42, 27.87s/it]
# ...
# loss: -27.86:  49%|████▉     | 49/100 [00:27<00:28,  1.81it/s]
#
# image update:  30%|███       | 3/10.0 [01:23<03:15, 27.94s/it]
# ...
# loss: -28.29:  99%|█████████▉| 99/100 [00:55<00:00,  1.78it/s]
#
# image update:  40%|████      | 4/10.0 [01:52<02:48, 28.07s/it]
# ...
# loss: -29.14:  49%|████▉     | 49/100 [00:27<00:29,  1.74it/s]
#
# image update:  50%|█████     | 5/10.0 [02:20<02:21, 28.37s/it]
# ...

# %%
import glob
from IPython.display import Image 

images = glob.glob("/content/*.png")
for image in images:
   img = Image(filename=image)
   display(img)

# %%
from deep_daze.cli import train as tti_deep_daze

# %%
name = "alejandro cejudo serrano"
tti_deep_daze(name, iterations = 100, epochs=5, overwrite=True)
# Out:
# Setting jit to False because torch version is not 1.7.1.
# Starting up...
# Imagining "alejandro_cejudo_serrano" from the depths of my weights...
# ...
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
#
# ...
# loss: -20.58:   1%|          | 1/100 [00:00<01:23,  1.19it/s]
# image updated at "./alejandro_cejudo_serrano.jpg"
# ...
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
#
# ...
# loss: -36.00:   1%|          | 1/100 [00:00<01:24,  1.18it/s]
# image updated at "./alejandro_cejudo_serrano.000001.jpg"
# ...
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
#
# ...
# loss: -40.84:   1%|          | 1/100 [00:00<01:23,  1.18it/s]
# image updated at "./alejandro_cejudo_serrano.000002.jpg"
# ...
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
#
# ...
# loss: -37.82:   1%|          | 1/100 [00:00<01:24,  1.17it/s]
# image updated at "./alejandro_cejudo_serrano.000003.jpg"
# ...
# loss: -38.97:  73%|███████▎  | 73/100 [01:00<00:22,  1.22it/s]
# ...
# ...
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
#
# ...

# %%
import glob
from IPython.display import Image 

images = glob.glob("/content/*.jpg")
for image in images:
   img = Image(filename=image)
   display(img)
