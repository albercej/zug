# %% [markdown]
# ### Crypto_Sentiment_Analysis_Twitter

# %%
"""
Twitter Sentiment Analysis in Python - A bot which will monitor, store and categorize Sentiment Analysis based on Twitter
for cryptocurrencies, and implement a strategy for profitable trading based on Bitcoin Barbie Bot (BBB) Strategy, described here:

https://medium.com/@BlockchainEng/crypto-trading-bot-sentiment-analysis-bot-bfbd8dd1df5a

Youtube Series Here:
6/30/2018
source of BitcoinPrice() code: https://gist.github.com/mattvukas/9146611
#

@BlockchainEng
Copyright 2018 - All Rights Reserved
"""
# Access data

#consumer_key    = '3jmA1BqasLHfItBXj3KnAIGFB'
#consumer_secret = 'imyEeVTctFZuK62QHmL1I0AUAMudg5HKJDfkx0oR7oFbFinbvA'
#access_token  = '265857263-pF1DRxgIcxUbxEEFtLwLODPzD3aMl6d4zOKlMnme'
#access_token_secret = 'uUFoOOGeNJfOYD3atlcmPtaxxniXxQzAU4ESJLopA1lbC'
#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)
#api = tweepy.API(auth,wait_on_rate_limit=True)

#
#Instructions: https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/

# %%
def run():
    #This Bot is to perform sentiment analysis, then implement a trade strategy based on sentiment and price
    """
    Monitor, collect and save tweets mentioning Cryptocurrency Y in file format.
    Perform Sentiment Analysis on a historic data set, and recent tweets during a specified time period (1 hour, 5 minutes, 1 day). Track and record historical values in file format. Visualize data through python script.
    Trade structure attempting to mimic this strategy:
    If Sentiment positive (‘buy’) and green candle (‘higher price’), wait to purchase coins.
    If candle decreases 2% (or more) in specified time period (5 minutes, 1 hour, 1 day), Purchase quantity of coin.
    Sell when price increases 5% (adjustable).
    To Reiterate, the functionality of of a bot to implement this strategy is based on a python script that will:

    Monitor all tweets mentioning X-Coin, perform sentiment analysis to determine buy/sell signalling from crypto-accounts
    Track Historical Values in CSV spreadsheet format
    Compare current/recent values to historic values
    Tweet out ‘Alerts’ based on strategy, and perform successful trades on Binance

    :return:
    """
    
import tweepy
import textblob
import time
#textblob.download_corpora()
from datetime import datetime
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
import matplotlib.pyplot as plt
import requests, json
from time import sleep


class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = '3jmA1BqasLHfItBXj3KnAIGFB'
        consumer_secret = 'imyEeVTctFZuK62QHmL1I0AUAMudg5HKJDfkx0oR7oFbFinbvA'
        access_token = '265857263-pF1DRxgIcxUbxEEFtLwLODPzD3aMl6d4zOKlMnme'
        access_token_secret = 'uUFoOOGeNJfOYD3atlcmPtaxxniXxQzAU4ESJLopA1lbC'

        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")

    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'

    def tweet_file(self):
        self.message="Sentiment Analysis by @BlockchainEng"
        self.filename='SentimentAnalysis.png'
        print(self)
        self.api.update_with_media(message = self.message, filename= self.filename)

    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []

        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)

            # parsing tweets one by one
            list_of_tweets = []
            for tweet in fetched_tweets:

                # empty dictionary to store required params of a tweet
                parsed_tweet = {}

                # saving text of tweet
                #tweet1 =
                #tweet1=TwitterClient.api.clean_tweet(tweet_text)
                parsed_tweet['text'] = tweet.text
                list_of_tweets.append(tweet.text)
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)

                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)

            # return parsed tweets
            with open('TweetHistory.txt', 'a+') as f1:
                for tweet in list_of_tweets:
                    try:
                        f1.write(tweet)
                    except:
                        pass

            return tweets

        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))

def main():
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    search_term = 'Bitcoin'
    list_coins=['Bitcoin'] #, 'Ethereum', 'EOS', 'Cryptocurrency', 'Blockchain', 'BTC'] #'Donald Trump', 'Barack Obama', 'George Washington']
    count1=200
    list_coin_val = []
    start_time = datetime.now()
    try:
        for i in range(0,60):
            #This For Loop controls how many data 'cycles' are collected before visualization and tweeting
            for coin in list_coins:
                tweets = api.get_tweets(query = coin, count = count1)

                # picking positive tweets from tweets
                ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
                # percentage of positive tweets
                print("\n\nTime: {}".format(str(datetime.now())))
                print("Sentiment Values for {}\nNumber of Tweets Analyzed: {}".format(coin, count1))
                positive_tweet_percentage = round(100*len(ptweets)/len(tweets),6)
                print("Positive tweets percentage: {} %".format(positive_tweet_percentage))
                # picking negative tweets from tweets
                ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
                # percentage of negative tweets
                negative_tweet_percentage = round(100*len(ntweets)/len(tweets),6)
                print("Negative tweets percentage: {} %".format(negative_tweet_percentage))
                # percentage of neutral tweets
                neutral_tweet_percentage = round(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets),6)
                print("Neutral tweets percentage: {} % \
                    ".format(neutral_tweet_percentage))
                current_price = getBitcoinPrice()
                list_coin_val.append([coin, positive_tweet_percentage, negative_tweet_percentage, neutral_tweet_percentage, str(datetime.now()), current_price])
                save_to_file(coin, positive_tweet_percentage, negative_tweet_percentage, neutral_tweet_percentage, datetime.now(), current_price, "SentimentHistorical.csv")
                print("Current Price: {}".format(getBitcoinPrice()))
                trading(current_price, positive_tweet_percentage, negative_tweet_percentage)    #used for Trading Signals
            time.sleep(30)
        end_time = datetime.now()
        print(list_coin_val, start_time, end_time)
    except:
        print("ERROR - COLLECTING DATA")
    try:
        #msg = 'Sentiment Analysis - Twitter \nvia @BlockchainEngineer \n\n #cryptocurrency #bitcoin #bitcointrading'
        #filename = 'SentimentAnalysis.png'
        #api.tweet_file()
        data_visualize(api, list_coin_val, start_time, end_time)
        #historic_data_viz(api)
    except:
        print("ERROR - COLLECTING DATA")

def save_to_file(coin, positive_tweet_percentage, negative_tweet_percentage, neutral_tweet_percentage, time, current_price, filename = "SentimentHistorical.csv"):
    with open(filename, 'a+') as  f:
        line = coin, positive_tweet_percentage, negative_tweet_percentage, neutral_tweet_percentage, time, current_price
        f.writelines(str(line) + '\n')
def getBitcoinPrice():
    URL = 'https://www.bitstamp.net/api/ticker/'
    try:
        r = requests.get(URL)
        priceFloat = float(json.loads(r.text)['last'])
        return priceFloat
    except requests.ConnectionError:
        print("Error querying Bitstamp API")

def tweet_file(self, message, filename):
    #message = "Sentiment Analysis by @BlockchainEng"
    #filename ='SentimentAnalysis.png'
    self.api.update_with_media(message, filename)

def historic_data_viz(self):
    #Load Historic Data and Visual into graph form for entire recorded amount
    historic_data_list = []
    i=0
    with open('SentimentHistorical.csv') as f1:
        lines = list(f1.readlines())
        for line in lines:
            print(line)
            data=list(line.split(','))
            print(data)
            if i==0:
                start_time=data[5]
            if i==len(f1.readlines()):
                end_time=data[5]
            historic_data_list.append(data)
            i+=1
    data_visualize(historic_data_list, start_time, end_time, self)

def trading(current_price, positive_sentiment_percent, negative_sentiment_percent):
    print("Positive Sentiment - Negative Sentiment (Net Positive)", positive_sentiment_percent-negative_sentiment_percent)
    if positive_sentiment_percent>0.3:
        #Buy
        #use Khal's Code to place order, entries & exits
        print("TEST - BUY SIGNAL")
        pass
    if negative_sentiment_percent>0.2:
        #Sell
        print("TEST - SELL SIGNAL")
        #use Khal's Code to place order, entries & exits
        pass

def data_visualize(api, list_coins, start_time, end_time):
    visualize_price = []
    name_list = []
    positive_tweet = []
    negative_tweet = []
    neutral_tweet = []
    time_list = []
    for coin in list_coins:
        print("COIN: ", coin)
        print(positive_tweet)
        print(coin[0])
        name_list.append(coin[0])
        positive_tweet.append(coin[1])
        print(coin[1])
        negative_tweet.append(coin[2])
        neutral_tweet.append(coin[3])
        time_list.append(coin[4])
        visualize_price.append(coin[5])
    #Converted to two axis on same graph - https://matplotlib.org/gallery/api/two_scales.html
    fig, ax1 = plt.subplots()

    color = 'black'
    ax1.set_xlabel('time')
    ax1.set_ylabel('Percentage', color=color)
    plt.title("Sentiment Analysis through Twitter \nCopyright 2018 (c) by @BlockchainEng")
    #ax1.plot(t, data1, color=color)
    ax1.plot(time_list, positive_tweet, 'g', label='Positive %')
    ax1.plot(time_list, negative_tweet, 'r', label='Negative %')
    ax1.plot(time_list, neutral_tweet, 'k', label = 'Neutral %')
    ax1.tick_params(axis='y', labelcolor=color)
    plt.legend()
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'blue'
    ax2.set_ylabel('Price ($)', color=color)  # we already handled the x-label with ax1
    #ax2.plot(t, data2, color=color)
    ax2.plot(time_list, visualize_price, 'b', label='Bitcoin Price (Bitstamp)')
    ax2.tick_params(axis='y', labelcolor=color)
    plt.legend()
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    """
    #print(positive_tweet)
    fig = plt.figure(1)
    plt.subplot(211)
    plt.plot(time_list, positive_tweet, 'g', label='Positive Tweet Percentage')
    plt.plot(time_list, negative_tweet, 'r', label='Negative Tweet Percentage')
    plt.plot(time_list, neutral_tweet, 'k', label = 'Neutral Tweet Percentage')
    plt.legend()
    plt.subplot(212)
    plt.plot(time_list, visualize_price, 'b', label='Bitcoin Price (Bitstamp)')
    plt.suptitle('{} Sentiment Analysis, 200 Tweets (each)\n{} - {} '.format(name_list[0], start_time, end_time))
    plt.legend()
    plt.ylabel('Percentage')
    plt.xlabel('Time')
    #plt.show()
    """
    plt.legend()
    #ax2.title('{} Sentiment Analysis, 200 Tweets (each)\n{} - {} '.format(name_list[0], start_time, end_time))
    filename='SentimentAnalysis.png' #+str(start_time).strip()+'.png'
    fig.savefig(filename)
    #tweet out fig and message
    msg = "@Twitter Sentiment Analysis for conversation around #Bitcoin - 200 tweets measured each cycle"
    msg+= "\n\n Includes price. \n\nvia @BlockchainEng \n\n #SentimentAnalysis #BitcoinTrading #Bitcoin"
    api.tweet_file()
    """
    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:10]:
        print(tweet['text'])

    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:10]:
        print(tweet['text'])
    """

if __name__ == "__main__":
    # calling main function
    while 1:
        main()
# Out:
# C:\Users\alber\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\alber\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\alber\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)
# Time: 2020-11-12 00:41:24.106720
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 35.164835 %
# Negative tweets percentage: 10.989011 %
# Neutral tweets percentage: 53.846154 %
# Current Price: 15759.55
# Positive Sentiment - Negative Sentiment (Net Positive) 24.175824
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:41:57.167866
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.078652 %
# Negative tweets percentage: 6.741573 %
# Neutral tweets percentage: 56.179775 %
# Current Price: 15750.58
# Positive Sentiment - Negative Sentiment (Net Positive) 30.337079
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:42:31.427483
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 34.482759 %
# Negative tweets percentage: 8.045977 %
# Neutral tweets percentage: 57.471264 %
# Current Price: 15747.59
# Positive Sentiment - Negative Sentiment (Net Positive) 26.436782
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:43:05.373330
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 38.372093 %
# Negative tweets percentage: 12.790698 %
# Neutral tweets percentage: 48.837209 %
# Current Price: 15742.11
# Positive Sentiment - Negative Sentiment (Net Positive) 25.581395
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:43:37.986835
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 39.534884 %
# Negative tweets percentage: 12.790698 %
# Neutral tweets percentage: 47.674419 %
# Current Price: 15742.04
# Positive Sentiment - Negative Sentiment (Net Positive) 26.744186
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:44:11.669511
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.5 %
# Negative tweets percentage: 15.909091 %
# Neutral tweets percentage: 46.590909 %
# Current Price: 15732.87
# Positive Sentiment - Negative Sentiment (Net Positive) 21.590909
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:44:46.146572
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.777778 %
# Negative tweets percentage: 15.555556 %
# Neutral tweets percentage: 46.666667 %
# Current Price: 15724.27
# Positive Sentiment - Negative Sentiment (Net Positive) 22.222222
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:45:18.699213
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 31.818182 %
# Negative tweets percentage: 13.636364 %
# Neutral tweets percentage: 54.545455 %
# Current Price: 15729.79
# Positive Sentiment - Negative Sentiment (Net Positive) 18.181818
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:45:51.189802
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 31.325301 %
# Negative tweets percentage: 15.662651 %
# Neutral tweets percentage: 53.012048 %
# Current Price: 15710.0
# Positive Sentiment - Negative Sentiment (Net Positive) 15.66265
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:46:25.450353
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 36.585366 %
# Negative tweets percentage: 10.97561 %
# Neutral tweets percentage: 52.439024 %
# Current Price: 15718.83
# Positive Sentiment - Negative Sentiment (Net Positive) 25.609756
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:47:01.812911
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.974684 %
# Negative tweets percentage: 8.860759 %
# Neutral tweets percentage: 53.164557 %
# Current Price: 15722.82
# Positive Sentiment - Negative Sentiment (Net Positive) 29.113925000000002
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:47:34.742739
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 33.766234 %
# Negative tweets percentage: 12.987013 %
# Neutral tweets percentage: 53.246753 %
# Current Price: 15729.64
# Positive Sentiment - Negative Sentiment (Net Positive) 20.779221
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:48:07.471527
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 39.74359 %
# Negative tweets percentage: 10.25641 %
# Neutral tweets percentage: 50.0 %
# Current Price: 15733.41
# Positive Sentiment - Negative Sentiment (Net Positive) 29.487179999999995
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:48:40.128481
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 39.759036 %
# Negative tweets percentage: 13.253012 %
# Neutral tweets percentage: 46.987952 %
# Current Price: 15723.7
# Positive Sentiment - Negative Sentiment (Net Positive) 26.506024000000004
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:49:13.089787
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 40.0 %
# Negative tweets percentage: 17.647059 %
# Neutral tweets percentage: 42.352941 %
# Current Price: 15733.4
# Positive Sentiment - Negative Sentiment (Net Positive) 22.352941
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:49:46.214616
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.349398 %
# Negative tweets percentage: 19.277108 %
# Neutral tweets percentage: 43.373494 %
# Current Price: 15718.7
# Positive Sentiment - Negative Sentiment (Net Positive) 18.072290000000002
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:50:22.100903
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 36.144578 %
# Negative tweets percentage: 20.481928 %
# Neutral tweets percentage: 43.373494 %
# Current Price: 15720.04
# Positive Sentiment - Negative Sentiment (Net Positive) 15.662650000000003
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:50:54.766145
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 36.144578 %
# Negative tweets percentage: 15.662651 %
# Neutral tweets percentage: 48.192771 %
# Current Price: 15715.46
# Positive Sentiment - Negative Sentiment (Net Positive) 20.481927000000002
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:51:27.457109
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.647059 %
# Negative tweets percentage: 11.764706 %
# Neutral tweets percentage: 50.588235 %
# Current Price: 15718.63
# Positive Sentiment - Negative Sentiment (Net Positive) 25.882353
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:52:01.975225
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 36.363636 %
# Negative tweets percentage: 10.227273 %
# Neutral tweets percentage: 53.409091 %
# Current Price: 15709.95
# Positive Sentiment - Negative Sentiment (Net Positive) 26.136363
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:52:35.020305
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.209302 %
# Negative tweets percentage: 6.976744 %
# Neutral tweets percentage: 55.813953 %
# Current Price: 15709.83
# Positive Sentiment - Negative Sentiment (Net Positive) 30.232558
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:53:10.394664
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 32.941176 %
# Negative tweets percentage: 11.764706 %
# Neutral tweets percentage: 55.294118 %
# Current Price: 15714.59
# Positive Sentiment - Negative Sentiment (Net Positive) 21.17647
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:53:44.222893
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 34.52381 %
# Negative tweets percentage: 15.47619 %
# Neutral tweets percentage: 50.0 %
# Current Price: 15712.01
# Positive Sentiment - Negative Sentiment (Net Positive) 19.047619999999995
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:54:17.092579
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 32.142857 %
# Negative tweets percentage: 15.47619 %
# Neutral tweets percentage: 52.380952 %
# Current Price: 15703.09
# Positive Sentiment - Negative Sentiment (Net Positive) 16.666666999999997
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:54:49.659638
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 36.046512 %
# Negative tweets percentage: 16.27907 %
# Neutral tweets percentage: 47.674419 %
# Current Price: 15700.0
# Positive Sentiment - Negative Sentiment (Net Positive) 19.767442
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:55:24.844773
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 30.681818 %
# Negative tweets percentage: 14.772727 %
# Neutral tweets percentage: 54.545455 %
# Current Price: 15703.13
# Positive Sentiment - Negative Sentiment (Net Positive) 15.909091
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:55:57.886218
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 27.058824 %
# Negative tweets percentage: 17.647059 %
# Neutral tweets percentage: 55.294118 %
# Current Price: 15704.56
# Positive Sentiment - Negative Sentiment (Net Positive) 9.411765000000003
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:56:33.520680
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 23.809524 %
# Negative tweets percentage: 17.857143 %
# Neutral tweets percentage: 58.333333 %
# Current Price: 15723.54
# Positive Sentiment - Negative Sentiment (Net Positive) 5.952380999999999
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:57:07.174267
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 27.906977 %
# Negative tweets percentage: 17.44186 %
# Neutral tweets percentage: 54.651163 %
# Current Price: 15726.06
# Positive Sentiment - Negative Sentiment (Net Positive) 10.465117000000003
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:57:41.427358
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 31.395349 %
# Negative tweets percentage: 17.44186 %
# Neutral tweets percentage: 51.162791 %
# Current Price: 15725.41
# Positive Sentiment - Negative Sentiment (Net Positive) 13.953489000000001
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:58:14.516903
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 33.72093 %
# Negative tweets percentage: 16.27907 %
# Neutral tweets percentage: 50.0 %
# Current Price: 15722.6
# Positive Sentiment - Negative Sentiment (Net Positive) 17.441860000000002
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:58:47.262707
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 35.227273 %
# Negative tweets percentage: 15.909091 %
# Neutral tweets percentage: 48.863636 %
# Current Price: 15709.66
# Positive Sentiment - Negative Sentiment (Net Positive) 19.318181999999997
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:59:20.805482
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 37.777778 %
# Negative tweets percentage: 14.444444 %
# Neutral tweets percentage: 47.777778 %
# Current Price: 15707.15
# Positive Sentiment - Negative Sentiment (Net Positive) 23.333333999999997
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 00:59:53.664364
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 30.0 %
# Negative tweets percentage: 18.888889 %
# Neutral tweets percentage: 51.111111 %
# Current Price: 15701.54
# Positive Sentiment - Negative Sentiment (Net Positive) 11.111111000000001
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 01:00:27.542765
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 32.978723 %
# Negative tweets percentage: 13.829787 %
# Neutral tweets percentage: 53.191489 %
# Current Price: 15719.66
# Positive Sentiment - Negative Sentiment (Net Positive) 19.148936000000003
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 01:01:00.514455
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 32.978723 %
# Negative tweets percentage: 11.702128 %
# Neutral tweets percentage: 55.319149 %
# Current Price: 15721.1
# Positive Sentiment - Negative Sentiment (Net Positive) 21.276595
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 01:01:32.750226
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 34.343434 %
# Negative tweets percentage: 11.111111 %
# Neutral tweets percentage: 54.545455 %
# Current Price: 15729.54
# Positive Sentiment - Negative Sentiment (Net Positive) 23.232323
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
#
#
# Time: 2020-11-12 01:02:05.495172
# Sentiment Values for Bitcoin
# Number of Tweets Analyzed: 200
# Positive tweets percentage: 33.684211 %
# Negative tweets percentage: 15.789474 %
# Neutral tweets percentage: 50.526316 %
# Current Price: 15708.95
# Positive Sentiment - Negative Sentiment (Net Positive) 17.894737
# TEST - BUY SIGNAL
# TEST - SELL SIGNAL
